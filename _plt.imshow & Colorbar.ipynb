# %%
import matplotlib.pyplot as plt
import matplotlib.image as img

# %%
plt.figure(figsize=(10,10))
image = img.imread('atta.png')
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(20,10))
image = img.imread('C:\\Users\\ATTA UR RAHMAN\\Desktop\\model-g249ac64b7_1920.jpg')
plt.imshow(image)
plt.axis('off')
plt.colorbar()
plt.show()

# %%
single_channel2_img = image[:,:,1]
plt.figure(figsize=(20,10))
image = img.imread('C:\\Users\\ATTA UR RAHMAN\\Desktop\\model-g249ac64b7_1920.jpg')
plt.imshow(single_channel2_img, cmap = 'Blues_r')
plt.axis('off')
plt.colorbar()
plt.show()
